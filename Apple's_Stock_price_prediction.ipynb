# %% [markdown]
# Dataset: I have used data of stock prices of 'Apple' from yahoo finance during the period

# %%
#Import Libraries
import yfinance as yf
import pandas as pd
import numpy as np

# %%
# Download Apple's historical stock data
df = yf.download(
    "AAPL",
    start="2013-01-01",
    end="2026-05-05",
    interval="1d",
    auto_adjust=False
)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df.head()
# Out:
# Price       Adj Close      Close       High        Low       Open     Volume
# Ticker           AAPL       AAPL       AAPL       AAPL       AAPL       AAPL
# Date
# 2013-01-02  16.581400  19.608213  19.821428  19.343929  19.779285  560518000
# 2013-01-03  16.372107  19.360714  19.631071  19.321428  19.567142  352965200
# 2013-01-04  15.916066  18.821428  19.236786  18.779642  19.177500  594333600
# 2013-01-07  15.822445  18.710714  18.903570  18.400000  18.642857  484156400
# 2013-01-08  15.865024  18.761070  18.996071  18.616072  18.900356  458707200

# %%
df.shape
# Out:
# (3354, 6)

# %%
# Display dataset summary
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3354 entries, 2013-01-02 to 2026-05-04
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Adj Close, AAPL)  3354 non-null   float64
#  1   (Close, AAPL)      3354 non-null   float64
#  2   (High, AAPL)       3354 non-null   float64
#  3   (Low, AAPL)        3354 non-null   float64
#  4   (Open, AAPL)       3354 non-null   float64
#  5   (Volume, AAPL)     3354 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 183.4 KB

# %%
df.isnull().sum()
# Out:
# Price      Ticker
# Adj Close  AAPL      0
# Close      AAPL      0
# High       AAPL      0
# Low        AAPL      0
# Open       AAPL      0
# Volume     AAPL      0
# dtype: int64

# %%
# Statistical summray
df.describe()
# Out:
# Price     Adj Close        Close         High          Low         Open  \
# Ticker         AAPL         AAPL         AAPL         AAPL         AAPL
# count   3354.000000  3354.000000  3354.000000  3354.000000  3354.000000
# mean      96.679143    99.155977   100.142708    98.084627    99.077900
# std       79.005373    78.624919    79.399010    77.782505    78.558215
# min       11.863237    13.947500    14.271429    13.753571    13.856071
# 25%       26.456369    29.165625    29.423125    28.941250    29.195625
# 50%       52.916906    55.618750    55.998749    54.856251    55.519999
# 75%      163.008427   165.975002   167.857498   164.475002   165.957497
# max      285.659271   286.190002   288.619995   283.299988   286.200012
#
# Price         Volume
# Ticker          AAPL
# count   3.354000e+03
# mean    1.425680e+08
# std     1.199127e+08
# min     1.791060e+07
# 25%     6.800870e+07
# 50%     1.048003e+08
# 75%     1.740057e+08
# max     1.460852e+09

# %%
# Saving the dataset
df.to_csv("apple_stock.csv")

# %%
# Display column names
df.columns
# Out:
# MultiIndex([('Adj Close', 'AAPL'),
#             (    'Close', 'AAPL'),
#             (     'High', 'AAPL'),
#             (      'Low', 'AAPL'),
#             (     'Open', 'AAPL'),
#             (   'Volume', 'AAPL')],
#            names=['Price', 'Ticker'])

# %%
# Removing ticker from column names
df.columns = df.columns.droplevel(1)

# %%
# Display column names
df.columns
# Out:
# Index(['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume'], dtype='object', name='Price')

# %%
df.head()
# Out:
# Price       Adj Close      Close       High        Low       Open     Volume
# Date
# 2013-01-02  16.581400  19.608213  19.821428  19.343929  19.779285  560518000
# 2013-01-03  16.372107  19.360714  19.631071  19.321428  19.567142  352965200
# 2013-01-04  15.916066  18.821428  19.236786  18.779642  19.177500  594333600
# 2013-01-07  15.822445  18.710714  18.903570  18.400000  18.642857  484156400
# 2013-01-08  15.865024  18.761070  18.996071  18.616072  18.900356  458707200

# %%
# display datatypes of all columns
df.dtypes
# Out:
# Price
# Adj Close    float64
# Close        float64
# High         float64
# Low          float64
# Open         float64
# Volume         int64
# dtype: object

# %%
# Display dataset summary
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3354 entries, 2013-01-02 to 2026-05-04
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Adj Close  3354 non-null   float64
#  1   Close      3354 non-null   float64
#  2   High       3354 non-null   float64
#  3   Low        3354 non-null   float64
#  4   Open       3354 non-null   float64
#  5   Volume     3354 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 183.4 KB

# %%
# Check missing values
df.isnull().sum()
# Out:
# Price
# Adj Close    0
# Close        0
# High         0
# Low          0
# Open         0
# Volume       0
# dtype: int64

# %%
# Save the cleaned dataset
df.to_csv('apple_stock.csv')

# %%
# Required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load cleaned dataset
df = pd.read_csv("apple_stock.csv", index_col=0)

# %%
df.head()
# Out:
#             Adj Close      Close       High        Low       Open     Volume
# Date
# 2013-01-02  16.581400  19.608213  19.821428  19.343929  19.779285  560518000
# 2013-01-03  16.372107  19.360714  19.631071  19.321428  19.567142  352965200
# 2013-01-04  15.916066  18.821428  19.236786  18.779642  19.177500  594333600
# 2013-01-07  15.822445  18.710714  18.903570  18.400000  18.642857  484156400
# 2013-01-08  15.865024  18.761070  18.996071  18.616072  18.900356  458707200

# %%
print(df.columns)
# Out:
# Index(['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume'], dtype='object')

# %%
df.tail()
# Out:
#              Adj Close       Close        High         Low        Open  \
# Date
# 2026-04-28  270.460815  270.709991  273.230011  268.660004  272.339996
# 2026-04-29  269.921326  270.170013  271.040009  267.040009  267.549988
# 2026-04-30  271.100250  271.350006  276.000000  268.140015  270.500000
# 2026-05-01  279.882141  280.140015  287.220001  278.369995  278.859985
# 2026-05-04  276.575165  276.829987  280.630005  274.859985  279.660004
#
#               Volume
# Date
# 2026-04-28  40018900
# 2026-04-29  30047900
# 2026-04-30  91848200
# 2026-05-01  79915400
# 2026-05-04  46668400

# %%
df.shape
# Out:
# (3354, 6)

# %%
# Count duplicate rows
print(df.duplicated().sum())
# Out:
# 0

# %%
# Display the first and last available dates
df.index.min()
df.index.max()
# Out:
# '2026-05-04'

# %%
# Plot Apple's closing price over time
plt.figure(figsize=(14,6))

plt.plot(
    df.index,
    df['Close'],
    label = "Close price"
)

plt.title("Apple Clopsing Price")
plt.xlabel('Year')
plt.ylabel('Price (USD)')

plt.legend()
plt.grid(True, linestyle="--", alpha=0.6)
plt.tight_layout()

plt.show()

# %%
# Plot trading volume over time
plt.figure(figsize=(14,6))

plt.plot(
    df.index,
    df["Volume"]
)

plt.title("Trading Volume")

plt.xlabel("Year")

plt.ylabel("Volume")

plt.grid(True, linestyle="--", alpha=0.6)
plt.tight_layout()

plt.show()

# %%
# Compute correlation matrix
# Compute the correlation matrix
correlation_matrix = df.corr(numeric_only=True)

# Display it
print(correlation_matrix)
# Out:
#            Adj Close     Close      High       Low      Open    Volume
# Adj Close   1.000000  0.999962  0.999843  0.999851  0.999704 -0.559340
# Close       0.999962  1.000000  0.999882  0.999880  0.999738 -0.560088
# High        0.999843  0.999882  1.000000  0.999832  0.999869 -0.558501
# Low         0.999851  0.999880  0.999832  1.000000  0.999876 -0.561430
# Open        0.999704  0.999738  0.999869  0.999876  1.000000 -0.559892
# Volume     -0.559340 -0.560088 -0.558501 -0.561430 -0.559892  1.000000

# %%
# Plot correlation heatmap

plt.figure(figsize=(8,6))

plt.imshow(correlation_matrix, cmap='coolwarm', interpolation = 'nearest')

plt.xticks(range(len(correlation_matrix.columns)),
            correlation_matrix.columns,
            rotation=45)

plt.yticks(range(len(correlation_matrix.columns)),
            correlation_matrix.columns)

plt.colorbar(label = "Correlation")
plt.title('correlation_matrix')

plt.tight_layout()

plt.show()

# %%
from statsmodels.tsa.stattools import adfuller

# %%
adf_result = adfuller(df["Close"])
print(f"ADF Statistic : {adf_result[0]:.4f}")
print(f"P-value       : {adf_result[1]:.4f}")
print("\nCritical Values")

for key, value in adf_result[4].items():
    print(f"{key} : {value:.4f}")
# Out:
# ADF Statistic : 0.6619
# P-value       : 0.9890
#
# Critical Values
# 1% : -3.4323
# 5% : -2.8624
# 10% : -2.5672

# %% [markdown]
# We fail to reject the null hypothesis, So conclude that it has unit root.

# %%
from statsmodels.tsa.stattools import kpss
kpss_result = kpss(df["Close"], regression="c")
print(f"KPSS Statistic : {kpss_result[0]:.4f}")
print(f"P-value        : {kpss_result[1]:.4f}")

print("\nCritical Values")
for key, value in kpss_result[3].items():
    print(f"{key} : {value}")
# Out:
# KPSS Statistic : 8.2612
# P-value        : 0.0100
#
# Critical Values
# 10% : 0.347
# 5% : 0.463
# 2.5% : 0.574
# 1% : 0.739
# /tmp/ipykernel_678/1515098655.py:5: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   kpss_result = kpss(df["Close"], regression="c")

# %% [markdown]
# First Order Differencing

# %%
df['Close_diff'] = df['Close'].diff()

# %%
df_diff = df.dropna()

# %%
fig, ax = plt.subplots()

ax.plot(df_diff['Close_diff'])
ax.set_xlabel('Year')
ax.set_ylabel('Price (USD)')

plt.tight_layout()
plt.show()

# %%
adf_diff = adfuller(df_diff['Close_diff'])

print(f'ADF Statistic: {adf_diff[0]}')
print(f'p-value: {adf_diff[1]}')
# Out:
# ADF Statistic: -20.446358022275085
# p-value: 0.0

# %%
from statsmodels.graphics.tsaplots import plot_acf

# %%
plt.figure(figsize=(12,5))
plot_acf(df_diff['Close_diff'], lags = 20)
plt.title("Autocorrelation Function (ACF)")
plt.tight_layout()
plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_pacf
plt.figure(figsize=(12,5))
plot_pacf(df_diff['Close_diff'], lags = 20, method ='ywm')
plt.title("Partial Autocorrelation Function (PACF)")
plt.tight_layout()
plt.show()

# %%
pip install pmdarima
# Out:
# Collecting pmdarima
#   Downloading pmdarima-2.1.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (8.5 kB)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.12/dist-packages (from pmdarima) (1.5.3)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /usr/local/lib/python3.12/dist-packages (from pmdarima) (3.0.12)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.12/dist-packages (from pmdarima) (2.0.2)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.12/dist-packages (from pmdarima) (2.2.2)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.12/dist-packages (from pmdarima) (1.6.1)
# Requirement already satisfied: scipy>=1.13.0 in /usr/local/lib/python3.12/dist-packages (from pmdarima) (1.16.3)
# Requirement already satisfied: statsmodels>=0.14.5 in /usr/local/lib/python3.12/dist-packages (from pmdarima) (0.14.6)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.12/dist-packages (from pmdarima) (2.5.0)
# Requirement already satisfied: setuptools!=50.0.0,>=42 in /usr/local/lib/python3.12/dist-packages (from pmdarima) (75.2.0)
# Requirement already satisfied: packaging>=17.1 in /usr/local/lib/python3.12/dist-packages (from pmdarima) (26.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.19->pmdarima) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.19->pmdarima) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.19->pmdarima) (2026.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.22->pmdarima) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from statsmodels>=0.14.5->pmdarima) (1.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=0.19->pmdarima) (1.17.0)
# Downloading pmdarima-2.1.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (689 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 689.1/689.1 kB 11.4 MB/s eta 0:00:00
# Installing collected packages: pmdarima
# Successfully installed pmdarima-2.1.1

# %%
from pmdarima import auto_arima

model = auto_arima( df['Close'], start_p=0, start_q=0, max_p=2, max_q=2, d=None, seasonal=False, trace=True, error_action='ignore', suppress_warnings=True, stepwise=True)
print(model.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=14716.989, Time=0.11 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=14718.434, Time=0.24 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=14718.445, Time=0.25 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=14719.174, Time=0.06 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=14720.947, Time=0.41 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0] intercept
# Total fit time: 1.092 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 3354
# Model:               SARIMAX(0, 1, 0)   Log Likelihood               -7356.494
# Date:                Mon, 20 Jul 2026   AIC                          14716.989
# Time:                        10:31:21   BIC                          14729.224
# Sample:                             0   HQIC                         14721.365
#                                - 3354
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0767      0.038      2.044      0.041       0.003       0.150
# sigma2         4.7121      0.040    119.099      0.000       4.635       4.790
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.56   Jarque-Bera (JB):             31309.53
# Prob(Q):                              0.46   Prob(JB):                         0.00
# Heteroskedasticity (H):              77.39   Skew:                             0.21
# Prob(H) (two-sided):                  0.00   Kurtosis:                        17.96
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
def compute_rsi(series, period=14):
    delta = series.diff()
    gain = delta.clip(lower=0)
    loss = -delta.clip(upper=0)

    avg_gain = gain.rolling(window=period).mean()
    avg_loss = loss.rolling(window=period).mean()

    rs = avg_gain / avg_loss
    rsi = 100 - (100 / (1 + rs))
    return rsi

df['RSI'] = compute_rsi(df['Close'], period=14)
df = df.dropna()

# %%
df.index = pd.to_datetime(df.index)
df = df.asfreq('B')
df = df.ffill()

# %%
len(df['Close'])
# Out:
# 3464

# %%
df['Volume_lag1'] = df['Volume'].shift(1)
df['RSI'] = compute_rsi(df['Close'], period=14)
df = df.dropna()
train_size = int(len(df) * 0.8)
train = df['Close'].iloc[:train_size]
test  = df['Close'].iloc[train_size:]
exog_train = df[['Volume_lag1', 'RSI']].iloc[:train_size]
exog_test  = df[['Volume_lag1', 'RSI']].iloc[train_size:]
print(len(train), len(exog_train))
print(len(test), len(exog_test))
n_test = len(test)
# Out:
# 2760 2760
# 690 690

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np

# %%
# Naive forecast that "tomorrow = today" or a simple moving average
naive_forecast = [train.iloc[-1]] * n_test
naive_rmse = np.sqrt(mean_squared_error(test, naive_forecast))
mae = mean_absolute_error(test, naive_forecast)
print(f" MAE with exog : {mae:.4f}")
print(f"Naive RMSE: {naive_rmse:.4f}")
# Out:
#  MAE with exog : 43.1401
# Naive RMSE: 52.4369

# %%
# Simple SARIMA (Without exogenous variable) that is ARIMA(0,1,0)
from statsmodels.tsa.statespace.sarimax import SARIMAX
model_plain = SARIMAX(train, order=(0,1,0))
results_plain = model_plain.fit(maxiter=1000)
forecast_plain = results_plain.get_forecast(steps=n_test)
predicted_plain = forecast_plain.predicted_mean

rmse_plain = np.sqrt(mean_squared_error(test, predicted_plain))
mae = mean_absolute_error(test, predicted_plain)
print(f"RMSE without exog: {rmse_plain:.4f}")
print(f" MAE without exog : {mae:.4f}")
# Out:
# RMSE without exog: 52.4369
#  MAE without exog : 43.1401

# %%
# SARIMA with exogenous variables that is ARIMAX(0,1,0)
model = SARIMAX(train, exog=exog_train, order=(0,1,0))
results = model.fit(maxiter=1000, method = "powell")

forecast = results.get_forecast(steps=n_test, exog=exog_test)
predicted_mean = forecast.predicted_mean
# Out:
# Optimization terminated successfully.
#          Current function value: 1.772824
#          Iterations: 2
#          Function evaluations: 88

# %%
# RMSE and MAE of SARIMAX(WITH EXOGENOUS VARIABLE) that is ARIMAX(0,1,0)
rmse = np.sqrt(mean_squared_error(test, predicted_mean))
mae = mean_absolute_error(test, predicted_mean)
print(f"RMSE with exog : {rmse:.4f}")
print(f" MAE with exog : {mae:.4f}")
# Out:
# RMSE with exog : 52.2706
#  MAE with exog : 42.8737

# %% [markdown]
# Clearly, We can see that SRAIMAX (ARIMAX) with exogenous variable performs better in this case.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14,6))
plt.plot(test.index, test, label='Actual', color='black')
plt.plot(test.index, predicted_mean, label='SARIMAX + exog')
plt.plot(test.index, predicted_plain, label='SARIMAX (no exog)')
plt.plot(test.index, naive_forecast, label='Naive', linestyle='--')
plt.legend()
plt.title('Forecast Comparison on Test Set')
plt.tight_layout()
plt.show()

# %%
import numpy as np
import pandas as pd
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_squared_error, mean_absolute_error

step_size = 5
all_preds = []
all_actuals = []
all_dates = []
history = df['Close'].iloc[:train_size].copy()
history_exog = df[['Volume_lag1', 'RSI']].iloc[:train_size].copy()
test_full = df['Close'].iloc[train_size:]
test_exog_full = df[['Volume_lag1', 'RSI']].iloc[train_size:]
n = len(test_full)

for start in range(0, n, step_size):
    end = min(start + step_size, n)
    model = SARIMAX(history, exog=history_exog, order=(0,1,0))
    results = model.fit(maxiter=1000, method='powell', disp=False)
    exog_chunk = test_exog_full.iloc[start:end]
    forecast = results.get_forecast(steps=len(exog_chunk), exog=exog_chunk)
# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14,6))
plt.plot(all_dates, all_actuals, label='Actual', color='black')
plt.plot(all_dates, all_preds, label='Walk-forward SARIMAX + exog', color='blue')
plt.legend()
plt.title('Walk-Forward ARIMA Forecast vs Actual')
plt.tight_layout()
plt.show()

# %%
dt = df[['Close']]

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# %%
training_size = int(len(dt) * 0.80)
test_size = len(dt) - training_size
train_raw = np.array(dt[:training_size]).reshape(-1,1)
test_raw = np.array(dt[training_size:]).reshape(-1,1)
scaler = MinMaxScaler(feature_range=(0,1))
train_data = scaler.fit_transform(train_raw)
test_data = scaler.transform(test_raw)

print(train_data.shape)
print(test_data.shape)
# Out:
# (2760, 1)
# (690, 1)

# %%
train_data
# Out:
# array([[0.01514069],
#        [0.01496652],
#        [0.01488434],
#        ...,
#        [0.89649457],
#        [0.89989176],
#        [0.90635747]])

# %%
def create_dataset(dataset, time_step = 1):
  dataX, dataY = [], []
  for i in range(len(dataset)-time_step-1):
    a = dataset[i:(i+time_step), 0]
    dataX.append(a)
    dataY.append(dataset[i + time_step, 0])
  return numpy.array(dataX), numpy.array(dataY)

# %%
import numpy
# reshape into X=t, X=t+1, X=t+2, X=t+3 and Y=t+4
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

# %%
X_train
# Out:
# array([[1.51406921e-02, 1.49665248e-02, 1.48843375e-02, ...,
#         6.35995394e-04, 1.17415298e-03, 3.65748170e-03],
#        [1.49665248e-02, 1.48843375e-02, 1.36260376e-02, ...,
#         1.17415298e-03, 3.65748170e-03, 5.47154401e-03],
#        [1.48843375e-02, 1.36260376e-02, 1.36260376e-02, ...,
#         3.65748170e-03, 5.47154401e-03, 5.92359513e-03],
#        ...,
#        [8.42084396e-01, 8.36714546e-01, 8.27783218e-01, ...,
#         9.61699208e-01, 9.61699208e-01, 9.63014205e-01],
#        [8.36714546e-01, 8.27783218e-01, 8.29481812e-01, ...,
#         9.61699208e-01, 9.63014205e-01, 9.25809271e-01],
#        [8.27783218e-01, 8.29481812e-01, 8.20933997e-01, ...,
#         9.63014205e-01, 9.25809271e-01, 8.96494570e-01]])

# %%
print(X_train.shape),  print(y_train.shape)
# Out:
# (2659, 100)
# (2659,)
# (None, None)

# %%
print(X_test.shape), print(y_test.shape)
# Out:
# (589, 100)
# (589,)
# (None, None)

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
len(X_test)
# Out:
# 589

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import GRU

# %%
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(100,1)))
model.add(LSTM(50, return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss = "mean_squared_error", optimizer = 'adam')
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 100, 50)        │        10,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 100, 50)        │        20,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 50)             │        20,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 50,851 (198.64 KB)
#  Trainable params: 50,851 (198.64 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, batch_size=64, verbose=1)
# Out:
# Epoch 1/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 8s 105ms/step - loss: 0.0225 - val_loss: 0.0086
# Epoch 2/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 7.5307e-04 - val_loss: 0.0171
# Epoch 3/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 96ms/step - loss: 6.7256e-04 - val_loss: 0.0174
# Epoch 4/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 99ms/step - loss: 6.5853e-04 - val_loss: 0.0140
# Epoch 5/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 109ms/step - loss: 5.9065e-04 - val_loss: 0.0114
# Epoch 6/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - loss: 5.9627e-04 - val_loss: 0.0092
# Epoch 7/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 5.9081e-04 - val_loss: 0.0097
# Epoch 8/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 97ms/step - loss: 5.4689e-04 - val_loss: 0.0082
# Epoch 9/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 97ms/step - loss: 4.9501e-04 - val_loss: 0.0105
# Epoch 10/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 110ms/step - loss: 4.8463e-04 - val_loss: 0.0100
# Epoch 11/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - loss: 4.5518e-04 - val_loss: 0.0070
# Epoch 12/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 110ms/step - loss: 4.9225e-04 - val_loss: 0.0098
# Epoch 13/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 98ms/step - loss: 4.0735e-04 - val_loss: 0.0075
# Epoch 14/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 96ms/step - loss: 4.4797e-04 - val_loss: 0.0107
# Epoch 15/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 112ms/step - loss: 3.9757e-04 - val_loss: 0.0115
# Epoch 16/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 97ms/step - loss: 4.0755e-04 - val_loss: 0.0034
# Epoch 17/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 110ms/step - loss: 3.5934e-04 - val_loss: 0.0063
# Epoch 18/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - loss: 3.6321e-04 - val_loss: 0.0028
# Epoch 19/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 99ms/step - loss: 3.2054e-04 - val_loss: 0.0066
# Epoch 20/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 112ms/step - loss:
# Epoch 87/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 107ms/step - loss: 1.0636e-04 - val_loss: 0.0010
# Epoch 88/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 97ms/step - loss: 1.2966e-04 - val_loss: 0.0046
# Epoch 89/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - loss: 1.4849e-04 - val_loss: 0.0015
# Epoch 90/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 110ms/step - loss: 1.0453e-04 - val_loss: 0.0017
# Epoch 91/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 97ms/step - loss: 1.0305e-04 - val_loss: 0.0021
# Epoch 92/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - loss: 9.9811e-05 - val_loss: 7.1309e-04
# Epoch 93/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 97ms/step - loss: 1.1357e-04 - val_loss: 6.7067e-04
# Epoch 94/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - loss: 1.0552e-04 - val_loss: 0.0023
# Epoch 95/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 111ms/step - loss: 1.0735e-04 - val_loss: 0.0014
# Epoch 96/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 97ms/step - loss: 1.1479e-04 - val_loss: 0.0015
# Epoch 97/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 1.0071e-04 - val_loss: 5.9699e-04
# Epoch 98/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 97ms/step - loss: 1.8167e-04 - val_loss: 7.1425e-04
# Epoch 99/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - loss: 1.1599e-04 - val_loss: 0.0014
# Epoch 100/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 109ms/step - loss: 1.0659e-04 - val_loss: 6.9432e-04

# %%
## Lets do the prediction and check performance metrics
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)
# Out:
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step

# %%
test_predict
# Out:
# array([[0.97998947],
#        [0.9576474 ],
#        [0.93927175],
#        [0.95878613],
#        [0.94768524],
#        [0.9602025 ],
#        [0.9701207 ],
#        [0.96807855],
#        [0.96262515],
#        [0.96754074],
#        [0.9556376 ],
#        [0.94428504],
#        [0.94150037],
#        [0.9394706 ],
#        [0.9297086 ],
#        [0.93163484],
#        [0.9269982 ],
#        [0.9318364 ],
#        [0.9438552 ],
#        [0.93024784],
#        [0.92455655],
#        [0.93540066],
#        [0.9250161 ],
#        [0.92207146],
#        [0.9170249 ],
#        [0.8895347 ],
#        [0.86387527],
#        [0.8617844 ],
#        [0.8597415 ],
#        [0.8686928 ],
#        [0.8801669 ],
#        [0.88190496],
#        [0.8700593 ],
#        [0.88299775],
#        [0.8792799 ],
#        [0.88467836],
#        [0.898823  ],
#        [0.91179895],
#        [0.8671909 ],
#        [0.8789246 ],
#        [0.87043756],
#        [0.8607636 ],
#        [0.8843337 ],
#        [0.87080383],
#        [0.871453  ],
#        [0.8651817 ],
#        [0.85773367],
#        [0.86334866],
#        [0.857613  ],
#        [0.8620247 ],
#        [0.85572374],
#        [0.8629158 ],
#        [0.8517649 ],
#        [0.8941826 ],
#        [0.89955837],
#        [0.8748123 ],
#        [0.8613778 ],
#        [0.8551437 ],
#        [0.84798265],
#        [0.8360325 ],
#        [0.8420384 ],
#        [0.8476413 ],
#        [0.8586722 ],
#        [0.8634567 ],
#        [0.85996866],
#        [0.8851664 ],
#        [0.86452377],
#        [0.8596667 ],
#        [0.88385916],
#        [0.9395933 ],
#        [0.9226895 ],
#        [0.93005735],
#        [0.93494284],
#        [0.942701  ],
#        [0.93219566],
#        [0.95333284],
#        [0.9571405 ],
#        [0.9691618 ],
#        [0.9692528 ],
#        [0.9694239 ],
#        [0.977226  ],
#        [0.9834526 ],
#        [0.97305566],
#        [0.95095724],
#        [0.9752758 ],
#        [0.9697684 ],
#        [0.96929157],
#        [0.97371364],
#        [0.9787352 ],
#        [0.9835851 ],
#        [0.99390817],
#        [0.9939663 ],
#        [1.0034851 ],
#        [0.99329674],
#        [1.0102094 ],
#        [0.98347694],
#        [1.075577  ],
#        [1.0920978 ],
#        [1.0923289 ],
#        [1.0870167 ],
#        [1.1145701 ],
#        [1.08975   ],
#        [1.0956929 ],
#        [1.0662435 ],
#        [1.0592386 ],
#        [1.0670553 ],
#        [1.0696663 ],
#        [1.0964262 ],
#        [1.0956675 ],
#        [1.0739259 ],
#        [1.121928  ],
#        [1.1298114 ],
#        [1.1330562 ],
#        [1.1349872 ],
#        [1.1649184 ],
#        [1.1637505 ],
#        [1.1687896 ],
#        [1.1963012 ],
#        [1.1505706 ],
#        [1.1859524 ],
#        [1.200792  ],
#        [1.1943793 ],
#        [1.1604029 ],
#        [1.1435468 ],
#        [1.151217  ],
#        [1.1450065 ],
#        [1.154399  ],
#        [1.1106484 ],
#        [1.1195713 ],
#        [1.1220992 ],
#        [1.1204205 ],
#        [1.1260445 ],
#        [1.1462603 ],
#        [1.1149356 ],
#        [1.1347928 ],
#        [1.0602452 ],
#        [1.0678566 ],
#        [1.0854071 ],
#        [1.0973605 ],
#        [1.1138359 ],
#        [1.1187077 ],
#        [1.141387  ],
#        [1.1371022 ],
#        [1.156508  ],
#        [1.1589435 ],
#        [1.1552309 ],
#        [1.1607802 ],
#        [1.1575563 ],
#        [1.1456497 ],
#        [1.1652938 ],
#        [1.1607602 ],
#        [1.1671176 ],
#        [1.1566623 ],
#        [1.181801  ],
#        [1.1683936 ],
#        [1.1722583 ],
#        [1.1319969 ],
#        [1.1329507 ],
#        [1.1442527 ],
#        [1.1279289 ],
#        [1.1351537 ],
#        [1.1295159 ],
#        [1.1472597 ],
#        [1.1427984 ],
#        [1.1418321 ],
#        [1.1027032 ],
#        [1.1183227 ],
#        [1.1390843 ],
#        [1.1821858 ],
#        [1.1643167 ],
#        [1.159692  ],
#        [1.1692724 ],
#        [1.1568167 ],
#        [1.1674249 ],
#        [1.1660708 ],
#        [1.1993928 ],
#        [1.1437024 ],
#        [1.1670388 ],
#        [1.1547331 ],
#        [1.1622924 ],
#        [1.1284264 ],
#        [1.1670064 ],
#        [1.1798112 ],
#        [1.1693224 ],
#        [1.1659807 ],
#        [1.1924751 ],
#        [1.1981776 ],
#        [1.1813895 ],
#        [1.1913377 ],
#        [1.2064357 ],
#        [1.2086558 ],
#        [1.2040066 ],
#        [1.1730007 ],
#        [1.183659  ],
#        [1.1856732 ],
#        [1.1962544 ],
#        [1.1956393 ],
#        [1.172864  ],
#        [1.1546614 ],
#        [1.1421684 ],
#        [1.1400294 ],
#        [1.1502454 ],
#        [1.142109  ],
#        [1.1766769 ],
#        [1.1623398 ],
#        [1.148002  ],
#        [1.1551    ],
#        [1.1568929 ],
#        [1.1748097 ],
#        [1.1476289 ],
#        [1.1765374 ],
#        [1.169297  ],
#        [1.1737157 ],
#        [1.1707934 ],
#        [1.1797394 ],
#        [1.1960738 ],
#        [1.2037538 ],
#        [1.20007   ],
#        [1.2019566 ],
#        [1.2169392 ],
#        [1.2252096 ],
#        [1.2415593 ],
#        [1.2380863 ],
#        [1.2394941 ],
#        [1.2382885 ],
#        [1.2638376 ],
#        [1.2601501 ],
#        [1.2527931 ],
#        [1.267394  ],
#        [1.262344  ],
#        [1.2829826 ],
#        [1.2916638 ],
#        [1.2515005 ],
#        [1.2815945 ],
#        [1.3014069 ],
#        [1.2949495 ],
#        [1.3189256 ],
#        [1.3098379 ],
#        [1.3178577 ],
#        [1.2929271 ],
#        [1.2806374 ],
#        [1.2757897 ],
#        [1.2776498 ],
#        [1.2334728 ],
#        [1.2507784 ],
#        [1.2575095 ],
#        [1.2339453 ],
#        [1.2493539 ],
#        [1.2447616 ],
#        [1.205623  ],
#        [1.2064284 ],
#        [1.1994624 ],
#        [1.2302845 ],
#        [1.1546854 ],
#        [1.1945649 ],
#        [1.1835184 ],
#        [1.1322957 ],
#        [1.1623138 ],
#        [1.151     ],
#        [1.1448265 ],
#        [1.195979  ],
#        [1.2314583 ],
#        [1.2234236 ],
#        [1.2160183 ],
#        [1.2084384 ],
#        [1.1556827 ],
#        [1.2056789 ],
#        [1.1850823 ],
#        [1.1937228 ],
#        [1.15826   ],
#        [1.1706326 ],
#        [1.2005379 ],
#        [1.2150538 ],
#        [1.2406309 ],
#        [1.2522488 ],
#        [1.2470121 ],
#        [1.2480597 ],
#        [1.2495321 ],
#        [1.2537546 ],
#        [1.2497827 ],
#        [1.2616985 ],
#        [1.2569938 ],
#        [1.2144611 ],
#        [1.2132543 ],
#        [1.2456921 ],
#        [1.2054774 ],
#        [1.2085223 ],
#        [1.2106222 ],
#        [1.204978  ],
#        [1.2328669 ],
#        [1.1454769 ],
#        [1.1339892 ],
#        [1.1171435 ],
#        [1.0689617 ],
#        [1.111954  ],
#        [1.1031653 ],
#        [1.0941854 ],
#        [1.1176195 ],
#        [1.1019583 ],
#        [1.1317654 ],
#        [1.1389992 ],
#        [1.1530983 ],
#        [1.13448   ],
#        [1.1542444 ],
#        [1.1085248 ],
#        [1.1485599 ],
#        [1.1436647 ],
#        [1.1457645 ],
#        [1.0120094 ],
#        [0.957562  ],
#        [0.93256795],
#        [0.8729239 ],
#        [1.0495273 ],
#        [0.9642105 ],
#        [1.0257653 ],
#        [1.0541073 ],
#        [1.0360951 ],
#        [0.9926455 ],
#        [1.0201806 ],
#        [1.0107298 ],
#        [0.9841949 ],
#        [1.0336709 ],
#        [1.0518922 ],
#        [1.068345  ],
#        [1.0731115 ],
#        [1.0775622 ],
#        [1.0829742 ],
#        [1.0887903 ],
#        [1.0917901 ],
#        [1.0396794 ],
#        [1.0135893 ],
#        [1.0197996 ],
#        [1.0006958 ],
#        [1.0130458 ],
#        [1.0190578 ],
#        [1.0943555 ],
#        [1.0899289 ],
#        [1.0867815 ],
#        [1.0863671 ],
#        [1.0831733 ],
#        [1.0664525 ],
#        [1.0583295 ],
#        [1.0298686 ],
#        [1.0324962 ],
#        [0.9932922 ],
#        [1.0025457 ],
#        [1.0336118 ],
#        [1.0250098 ],
#        [1.0253451 ],
#        [1.0336764 ],
#        [1.0358113 ],
#        [1.0445223 ],
#        [1.0395364 ],
#        [1.0264626 ],
#        [1.0508885 ],
#        [1.0282624 ],
#        [1.0404366 ],
#        [1.0146952 ],
#        [1.0220772 ],
#        [1.0041401 ],
#        [1.019272  ],
#        [0.99918056],
#        [1.0088465 ],
#        [1.0082763 ],
#        [1.0346528 ],
#        [1.0322487 ],
#        [1.024826  ],
#        [1.0362415 ],
#        [1.0291288 ],
#        [1.0302416 ],
#        [1.0564628 ],
#        [1.0656476 ],
#        [1.0919719 ],
#        [1.0932665 ],
#        [1.0926105 ],
#        [1.0708046 ],
#        [1.0769156 ],
#        [1.0821439 ],
#        [1.0871514 ],
#        [1.0785584 ],
#        [1.0656345 ],
#        [1.0735074 ],
#        [1.0778251 ],
#        [1.0750473 ],
#        [1.0843906 ],
#        [1.0906442 ],
#        [1.1008257 ],
#        [1.0966711 ],
#        [1.0955027 ],
#        [1.0970826 ],
#        [1.0970877 ],
#        [1.0788816 ],
#        [1.0703013 ],
#        [1.0638299 ],
#        [1.0313218 ],
#        [1.0471822 ],
#        [1.0408568 ],
#        [1.1066481 ],
#        [1.1332647 ],
#        [1.1830809 ],
#        [1.1571112 ],
#        [1.1805428 ],
#        [1.197082  ],
#        [1.1833658 ],
#        [1.1805048 ],
#        [1.1775255 ],
#        [1.1752453 ],
#        [1.1464578 ],
#        [1.15059   ],
#        [1.1696483 ],
#        [1.1581244 ],
#        [1.1778202 ],
#        [1.1810284 ],
#        [1.1926147 ],
#        [1.1869367 ],
#        [1.1888084 ],
#        [1.1727033 ],
#        [1.2351936 ],
#        [1.2205852 ],
#        [1.2233185 ],
#        [1.2143607 ],
#        [1.1927204 ],
#        [1.1507452 ],
#        [1.1886848 ],
#        [1.201585  ],
#        [1.2116989 ],
#        [1.2209046 ],
#        [1.2237482 ],
#        [1.2151769 ],
#        [1.2680483 ],
#        [1.314883  ],
#        [1.2828604 ],
#        [1.2836466 ],
#        [1.3146698 ],
#        [1.2882406 ],
#        [1.291762  ],
#        [1.294285  ],
#        [1.2972184 ],
#        [1.3080438 ],
#        [1.3102806 ],
#        [1.3012807 ],
#        [1.3052484 ],
#        [1.3148819 ],
#        [1.2837344 ],
#        [1.239559  ],
#        [1.2778552 ],
#        [1.2625519 ],
#        [1.2773988 ],
#        [1.262949  ],
#        [1.3006479 ],
#        [1.3507692 ],
#        [1.3299346 ],
#        [1.3106506 ],
#        [1.3282509 ],
#        [1.3387029 ],
#        [1.3702471 ],
#        [1.3573985 ],
#        [1.3672684 ],
#        [1.3750964 ],
#        [1.3628098 ],
#        [1.3600792 ],
#        [1.3689594 ],
#        [1.3652216 ],
#        [1.3650525 ],
#        [1.3581985 ],
#        [1.3685727 ],
#        [1.4028661 ],
#        [1.3745352 ],
#        [1.3848916 ],
#        [1.3791033 ],
#        [1.3467652 ],
#        [1.3635603 ],
#        [1.3644339 ],
#        [1.347101  ],
#        [1.3922938 ],
#        [1.4009119 ],
#        [1.4012102 ],
#        [1.4065964 ],
#        [1.4031565 ],
#        [1.4118319 ],
#        [1.4346884 ],
#        [1.4422224 ],
#        [1.4244745 ],
#        [1.4113988 ],
#        [1.4059684 ],
#        [1.4024336 ],
#        [1.4000107 ],
#        [1.4131885 ],
#        [1.4029015 ],
#        [1.4102639 ],
#        [1.3806614 ],
#        [1.3984954 ],
#        [1.3730507 ],
#        [1.3863385 ],
#        [1.3922846 ],
#        [1.3699423 ],
#        [1.3910812 ],
#        [1.3914224 ],
#        [1.3889558 ],
#        [1.3883357 ],
#        [1.3905575 ],
#        [1.3841676 ],
#        [1.3786508 ],
#        [1.3814269 ],
#        [1.3740997 ],
#        [1.3523263 ],
#        [1.3307394 ],
#        [1.3283558 ],
#        [1.3211586 ],
#        [1.3268253 ],
#        [1.3314464 ],
#        [1.334754  ],
#        [1.3262292 ],
#        [1.3181983 ],
#        [1.3036687 ],
#        [1.3093934 ],
#        [1.2468587 ],
#        [1.2803168 ],
#        [1.2732831 ],
#        [1.2698308 ],
#        [1.3231984 ],
#        [1.3184524 ],
#        [1.3058542 ],
#        [1.3252313 ],
#        [1.3223749 ],
#        [1.3889381 ],
#        [1.3551781 ],
#        [1.4127444 ],
#        [1.3848094 ],
#        [1.4070795 ],
#        [1.3759252 ],
#        [1.3818455 ],
#        [1.3931057 ],
#        [1.2942864 ],
#        [1.3041241 ],
#        [1.3065481 ],
#        [1.3561226 ],
#        [1.3401237 ],
#        [1.3235137 ],
#        [1.3618972 ],
#        [1.353481  ],
#        [1.3934829 ],
#        [1.3897768 ],
#        [1.3800693 ],
#        [1.3272297 ],
#        [1.355008  ],
#        [1.3359253 ],
#        [1.333412  ],
#        [1.3234862 ],
#        [1.309379  ],
#        [1.3333982 ],
#        [1.3294356 ],
#        [1.3301783 ],
#        [1.2978748 ],
#        [1.2742409 ],
#        [1.3040742 ],
#        [1.2991767 ],
#        [1.2708756 ],
#        [1.2794373 ],
#        [1.2697275 ],
#        [1.2950584 ],
#        [1.2858791 ],
#        [1.2947885 ],
#        [1.2937965 ],
#        [1.2651353 ],
#        [1.2627436 ],
#        [1.3114212 ],
#        [1.300478  ],
#        [1.3056912 ],
#        [1.3061458 ],
#        [1.3233048 ],
#        [1.279362  ],
#        [1.3335955 ],
#        [1.3217365 ],
#        [1.3226838 ],
#        [1.3173655 ],
#        [1.3162955 ],
#        [1.3666416 ],
#        [1.3234395 ],
#        [1.3867354 ],
#        [1.3795056 ],
#        [1.332768  ],
#        [1.4041162 ],
#        [1.3721756 ],
#        [1.3670557 ],
#        [1.3522354 ],
#        [1.378508  ],
#        [1.3630456 ],
#        [1.3778335 ]], dtype=float32)

# %%
len(test_predict)
# Out:
# 589

# %%
import math

# %%
y_train_actual = scaler.inverse_transform(y_train.reshape(-1, 1))
y_test_actual = scaler.inverse_transform(y_test.reshape(-1, 1))

train_predict = scaler.inverse_transform(train_predict)
test_predict = scaler.inverse_transform(test_predict)

train_rmse = math.sqrt(mean_squared_error(y_train_actual, train_predict))
test_rmse = math.sqrt(mean_squared_error(y_test_actual, test_predict))

print(f"Train RMSE: {train_rmse:.4f}")
print(f"Test RMSE: {test_rmse:.4f}")
# Out:
# Train RMSE: 1.9021
# Test RMSE: 4.8089

# %%
from sklearn.metrics import mean_absolute_error
test_mae = mean_absolute_error(y_test_actual, test_predict)
print(f"Test MAE: {test_mae:.4f}")
# Out:
# Test MAE: 3.5899

# %%
from sklearn.metrics import r2_score

print("LSTM R2:", r2_score(y_test_actual, test_predict))
# Out:
# LSTM R2: 0.9747883522988307

# %%
## Plotting
dt_values = dt.values
# shift train predictions for plotting
look_back=100
trainPredictPlot = numpy.empty_like(dt_values)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict)+look_back, :] = train_predict
# shift test predictions for plotting
testPredictPlot = numpy.empty_like(dt_values)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(dt_values)-1, :] = test_predict
# plot baseline and predictions
plt.figure(figsize=(14,6))
plt.plot(dt_values, label='Actual')
plt.plot(trainPredictPlot, label='Train Predict')
plt.plot(testPredictPlot, label='Test Predict')
plt.legend()
plt.title('LSTM: Actual vs Predicted')
plt.show()

# %% [markdown]
# **Now Model GRU**

# %%
model = Sequential()
model.add(GRU(50, return_sequences=True, input_shape=(100,1)))
model.add(GRU(50, return_sequences=True))
model.add(GRU(50))
model.add(Dense(1))
model.compile(loss = "mean_squared_error", optimizer = 'adam')
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 100, 50)        │         7,950 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_1 (GRU)                     │ (None, 100, 50)        │        15,300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_2 (GRU)                     │ (None, 50)             │        15,300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 38,601 (150.79 KB)
#  Trainable params: 38,601 (150.79 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, batch_size=64, verbose=1)
# Out:
# Epoch 1/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - loss: 0.0203 - val_loss: 0.0017
# Epoch 2/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 124ms/step - loss: 3.0306e-04 - val_loss: 0.0020
# Epoch 3/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 10s 127ms/step - loss: 2.0990e-04 - val_loss: 0.0019
# Epoch 4/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 11s 139ms/step - loss: 2.0149e-04 - val_loss: 0.0021
# Epoch 5/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 138ms/step - loss: 1.8618e-04 - val_loss: 0.0011
# Epoch 6/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 9s 220ms/step - loss: 1.8546e-04 - val_loss: 0.0018
# Epoch 7/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 9s 177ms/step - loss: 1.7098e-04 - val_loss: 0.0021
# Epoch 8/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 138ms/step - loss: 1.6559e-04 - val_loss: 0.0011
# Epoch 9/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 10s 140ms/step - loss: 1.6500e-04 - val_loss: 0.0018
# Epoch 10/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 10s 141ms/step - loss: 1.5103e-04 - val_loss: 0.0018
# Epoch 11/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 124ms/step - loss: 1.4268e-04 - val_loss: 0.0014
# Epoch 12/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 10s 126ms/step - loss: 1.3838e-04 - val_loss: 0.0016
# Epoch 13/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 10s 129ms/step - loss: 1.5108e-04 - val_loss: 0.0012
# Epoch 14/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 131ms/step - loss: 1.4502e-04 - val_loss: 0.0012
# Epoch 15/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 132ms/step - loss: 1.2496e-04 - val_loss: 0.0014
# Epoch 16/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 134ms/step - loss: 1.2434e-04 - val_loss: 0.0012
# Epoch 17/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 165ms/step - loss: 1.1949e-04 - val_loss: 9.0187e-04
# Epoch 18/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 9s 124ms/step - loss: 1.2550e-04 - val_loss: 0.0015
# Epoch 19/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 10s 127ms/step - loss: 1.4437e-04 - val_loss: 9.0254e-04
# Epoch 20/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 138ms/step - loss: 1.2657e-04 - val_loss: 7.2972e-04
# Epoch 21/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 127ms/step - loss: 1.0943e-04 - val_loss: 0.0012
# Epoch 22/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 138ms/step - loss: 1.1722e-04 - val_loss: 9.3423e-04
# Epoch 23/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 125ms/step - loss: 1.0889e-04 - val_loss: 0.0010
# Epoch 24/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 137ms/step - loss: 1.0703e-04 - val_loss: 0.0010
# Epoch 25/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - loss: 1.0724e-04 - val_loss: 5.7475e-04
# Epoch 26/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 124ms/step - loss: 1.2146e-04 - val_loss: 7.0718e-04
# Epoch 27/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 136ms/step - loss: 1.1116e-04 - val_loss: 0.0012
# Epoch 28/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 10s 123ms/step - loss: 1.1147e-04 - val_loss: 7.6451e-04
# Epoch 29/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 138ms/step - loss: 1.3535e-04 - val_loss: 0.0018
# Epoch 30/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 125ms/step - loss: 1.1390e-04 - val_loss: 0.0013
# Epoch 31/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 10s 127ms/step - loss: 1.0860e-04 - val_loss: 6.6754e-04
# Epoch 32/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 139ms/step - loss: 1.0370e-04 - val_loss: 8.4535e-04
# Epoch 33/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 126ms/step - loss: 1.1096e-04 - val_loss: 6.5489e-04
# Epoch 34/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 138ms/step - loss: 1.2430e-04 - val_loss: 0.0016
# Epoch 35/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 124ms/step - loss: 1.3506e-04 - val_loss: 7.2513e-04
# Epoch 36/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 138ms/step - loss: 9.8434e-05 - val_loss: 7.8039e-04
# Epoch 37/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 126ms/step - loss: 9.2859e-05 - val_loss: 0.0013
# Epoch 38/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 10s 125ms/step - loss: 9.5084e-05 - val_loss: 5.6204e-04
# Epoch 39/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 138ms/step - loss: 1.1859e-04 - val_loss: 7.4500e-04
# Epoch 40/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 125ms/step - loss: 9.2962e-05 - val_loss: 9.2085e-04
# Epoch 41/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 10s 127ms/step - loss: 1.0509e-04 - val_loss: 4.9297e-04
# Epoch 42/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 139ms/step - loss: 9.8984e-05 - val_loss: 5.0319e-04
# Epoch 43/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 10s 125ms/step - loss: 1.1258e-04 - val_loss: 0.0011
# Epoch 44/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 10s 125ms/step - loss: 9.6523e-05 - val_loss: 7.2612e-04
# Epoch 45/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 10s 126ms/step - loss: 9.2074e-05 - val_loss: 5.4012e-04
# Epoch 46/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 141ms/step - loss: 1.0579e-04 - val_loss: 7.0146e-04
# Epoch 47/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 10s 138ms/step - loss: 9.5270e-05 - val_loss: 5.3243e-04
# Epoch 48/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 128ms/step - loss: 9.2829e-05 - val_loss: 6.6407e-04
# Epoch 49/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 10s 126ms/step - loss: 8.8990e-05 - val_loss: 7.9228e-04
# Epoch 50/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 10s 126ms/step - loss: 8.9420e-05 - val_loss: 6.1815e-04
# Epoch 51/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 140ms/step - loss: 9.4609e-05 - val_loss: 0.0010
# Epoch 52/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 10s 127ms/step - loss: 1.0254e-04 - val_loss: 9.4759e-04
# Epoch 53/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 139ms/step - loss: 1.1317e-04 - val_loss: 7.2462e-04
# Epoch 54/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 127ms/step - loss: 1.5285e-04 - val_loss: 7.0950e-04
# Epoch 55/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 141ms/step - loss: 1.0929e-04 - val_loss: 4.5725e-04
# Epoch 56/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 125ms/step - loss: 1.1839e-04 - val_loss: 5.0298e-04
# Epoch 57/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 10s 128ms/step - loss: 1.2695e-04 - val_loss: 6.3004e-04
# Epoch 58/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 141ms/step - loss: 9.4260e-05 - val_loss: 4.6341e-04
# Epoch 59/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 10s 144ms/step - loss: 9.6453e-05 - val_loss: 9.4818e-04
# Epoch 60/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 125ms/step - loss: 1.0926e-04 - val_loss: 6.6819e-04
# Epoch 61/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 10s 126ms/step - loss: 9.4563e-05 - val_loss: 0.0018
# Epoch 62/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 140ms/step - loss: 1.0293e-04 - val_loss: 0.0014
# Epoch 63/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 10s 141ms/step - loss: 1.3304e-04 - val_loss: 0.0013
# Epoch 64/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 126ms/step - loss: 9.5405e-05 - val_loss: 0.0011
# Epoch 65/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 11s 132ms/step - loss: 9.1916e-05 - val_loss: 0.0010
# Epoch 66/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 125ms/step - loss: 8.9241e-05 - val_loss: 0.0013
# Epoch 67/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 137ms/step - loss: 1.3105e-04 - val_loss: 4.5414e-04
# Epoch 68/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 125ms/step - loss: 1.6027e-04 - val_loss: 0.0012
# Epoch 69/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 139ms/step - loss: 1.0380e-04 - val_loss: 9.0200e-04
# Epoch 70/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 126ms/step - loss: 9.9142e-05 - val_loss: 4.7009e-04
# Epoch 71/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 10s 126ms/step - loss: 1.0869e-04 - val_loss: 8.8350e-04
# Epoch 72/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 138ms/step - loss: 1.1829e-04 - val_loss: 7.5333e-04
# Epoch 73/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 127ms/step - loss: 8.9087e-05 - val_loss: 6.2468e-04
# Epoch 74/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 139ms/step - loss: 9.4520e-05 - val_loss: 6.2821e-04
# Epoch 75/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 127ms/step - loss: 1.0505e-04 - val_loss: 4.6758e-04
# Epoch 76/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 139ms/step - loss: 1.0643e-04 - val_loss: 5.9962e-04
# Epoch 77/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 10s 138ms/step - loss: 8.7917e-05 - val_loss: 5.7408e-04
# Epoch 78/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 125ms/step - loss: 8.8191e-05 - val_loss: 6.1372e-04
# Epoch 79/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 141ms/step - loss: 9.3367e-05 - val_loss: 4.9238e-04
# Epoch 80/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 128ms/step - loss: 1.1259e-04 - val_loss: 8.3295e-04
# Epoch 81/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 10s 127ms/step - loss: 9.9345e-05 - val_loss: 8.3123e-04
# Epoch 82/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 11s 132ms/step - loss: 8.8207e-05 - val_loss: 0.0012
# Epoch 83/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 11s 142ms/step - loss: 1.1059e-04 - val_loss: 0.0021
# Epoch 84/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 128ms/step - loss: 1.1078e-04 - val_loss: 7.3522e-04
# Epoch 85/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 10s 126ms/step - loss: 8.6637e-05 - val_loss: 6.9013e-04
# Epoch 86/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 139ms/step - loss: 9.9867e-05 - val_loss: 7.0139e-04
# Epoch 87/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 10s 138ms/step - loss: 1.0403e-04 - val_loss: 4.8707e-04
# Epoch 88/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 126ms/step - loss: 1.0149e-04 - val_loss: 4.6752e-04
# Epoch 89/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 10s 127ms/step - loss: 8.6808e-05 - val_loss: 6.1221e-04
# Epoch 90/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 10s 127ms/step - loss: 9.2442e-05 - val_loss: 6.0565e-04
# Epoch 91/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 143ms/step - loss: 9.7138e-05 - val_loss: 8.3539e-04
# Epoch 92/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 9s 125ms/step - loss: 1.4026e-04 - val_loss: 0.0022
# Epoch 93/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 140ms/step - loss: 1.1965e-04 - val_loss: 6.4306e-04
# Epoch 94/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 125ms/step - loss: 9.2037e-05 - val_loss: 0.0010
# Epoch 95/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 139ms/step - loss: 1.0787e-04 - val_loss: 0.0013
# Epoch 96/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 127ms/step - loss: 9.8580e-05 - val_loss: 7.1101e-04
# Epoch 97/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 10s 127ms/step - loss: 9.7579e-05 - val_loss: 5.0154e-04
# Epoch 98/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 138ms/step - loss: 1.0555e-04 - val_loss: 4.6522e-04
# Epoch 99/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 10s 141ms/step - loss: 1.0407e-04 - val_loss: 0.0014
# Epoch 100/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 128ms/step - loss: 1.1263e-04 - val_loss: 4.8034e-04

# %%
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)
# Out:
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step

# %%
len(test_predict)
# Out:
# 589

# %%
y_train_actual = scaler.inverse_transform(y_train.reshape(-1, 1))
y_test_actual = scaler.inverse_transform(y_test.reshape(-1, 1))

train_predict = scaler.inverse_transform(train_predict)
test_predict = scaler.inverse_transform(test_predict)

train_rmse = math.sqrt(mean_squared_error(y_train_actual, train_predict))
test_rmse = math.sqrt(mean_squared_error(y_test_actual, test_predict))

print(f"Train RMSE: {train_rmse:.4f}")
print(f"Test RMSE: {test_rmse:.4f}")
# Out:
# Train RMSE: 2.1621
# Test RMSE: 3.9998

# %%
from sklearn.metrics import mean_absolute_error
test_mae = mean_absolute_error(y_test_actual, test_predict)
print(f"Test MAE: {test_mae:.4f}")
# Out:
# Test MAE: 2.8845

# %%
from sklearn.metrics import r2_score

print("GRU R2:", r2_score(y_test_actual, test_predict))
# Out:
# GRU R2: 0.9825582708692195

# %%
## Plotting
dt_values = dt.values
# shift train predictions for plotting
look_back=100
trainPredictPlot = numpy.empty_like(dt_values)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict)+look_back, :] = train_predict
# shift test predictions for plotting
testPredictPlot = numpy.empty_like(dt_values)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(dt_values)-1, :] = test_predict
# plot baseline and predictions
plt.figure(figsize=(14,6))
plt.plot(dt_values, label='Actual')
plt.plot(trainPredictPlot, label='Train Predict')
plt.plot(testPredictPlot, label='Test Predict')
plt.legend()
plt.title('GRU: Actual vs Predicted')
plt.show()

# %%
plt.figure(figsize=(10,5))

models = ["LSTM", "GRU"]
rmse = [4.9111, 6.6438]

plt.bar(models, rmse)

plt.title("RMSE Comparison")
plt.ylabel("RMSE")
plt.show()

# %% [markdown]
# ### Best performining model is LSTM. So we will predict next 30 days using LSTM model

# %%
test_data
# Out:
# array([[0.88959059],
#        [0.87813871],
#        [0.88652215],
#        [0.88252214],
#        [0.89874113],
#        [0.90476848],
#        [0.8851523 ],
#        [0.8766044 ],
#        [0.88131667],
#        [0.88838512],
#        [0.86581011],
#        [0.85742658],
#        [0.85885128],
#        [0.86170058],
#        [0.87561816],
#        [0.86822096],
#        [0.87512503],
#        [0.88197425],
#        [0.89611106],
#        [0.90433012],
#        [0.90104246],
#        [0.9087684 ],
#        [0.91375466],
#        [0.90356301],
#        [0.90285067],
#        [0.89424801],
#        [0.88707003],
#        [0.88498793],
#        [0.87085113],
#        [0.87150862],
#        [0.87391956],
#        [0.86109784],
#        [0.83802963],
#        [0.84531721],
#        [0.85665948],
#        [0.85928964],
#        [0.87682363],
#        [0.89654942],
#        [0.89150832],
#        [0.90564512],
#        [0.91983677],
#        [0.92569966],
#        [0.92306958],
#        [0.94493224],
#        [0.93616529],
#        [0.95063084],
#        [0.95375404],
#        [0.96306905],
#        [0.96295944],
#        [0.97260311],
#        [0.96816483],
#        [0.97183601],
#        [0.97183601],
#        [0.96449366],
#        [0.96350733],
#        [0.96684975],
#        [0.961206  ],
#        [0.96438405],
#        [0.97145249],
#        [0.96153475],
#        [0.98339749],
#        [0.97737023],
#        [0.988055  ],
#        [0.99594531],
#        [0.98208241],
#        [0.99046594],
#        [1.00827391],
#        [1.00909579],
#        [1.00613696],
#        [0.99693156],
#        [1.00268492],
#        [0.99112344],
#        [0.99030148],
#        [0.98438383],
#        [0.98438383],
#        [0.98137015],
#        [0.98191804],
#        [0.98427421],
#        [0.97852085],
#        [0.97852085],
#        [0.94076795],
#        [0.93315162],
#        [0.92032989],
#        [0.91632989],
#        [0.94032959],
#        [0.93802826],
#        [0.94378162],
#        [0.94049396],
#        [0.94230217],
#        [0.94230217],
#        [0.92975443],
#        [0.92454895],
#        [0.95715131],
#        [0.97320585],
#        [0.98597281],
#        [0.99304117],
#        [0.98931523],
#        [0.98750703],
#        [0.97791812],
#        [0.97413733],
#        [0.95391842],
#        [0.93397349],
#        [0.94745279],
#        [0.94191865],
#        [0.95194584],
#        [0.96082249],
#        [0.96142522],
#        [0.95545272],
#        [0.95835678],
#        [0.94904178],
#        [0.93748029],
#        [0.93260365],
#        [0.93101466],
#        [0.92252161],
#        [0.92252161],
#        [0.91841208],
#        [0.92257646],
#        [0.93380911],
#        [0.92367232],
#        [0.91622036],
#        [0.92427505],
#        [0.91764497],
#        [0.9139738 ],
#        [0.9080013 ],
#        [0.88301535],
#        [0.85572799],
#        [0.85024861],
#        [0.84959112],
#        [0.85907041],
#        [0.87013878],
#        [0.87276886],
#        [0.86126222],
#        [0.87150862],
#        [0.86942643],
#        [0.87545378],
#        [0.88838512],
#        [0.90257668],
#        [0.86257721],
#        [0.86756347],
#        [0.859728  ],
#        [0.85348151],
#        [0.87320722],
#        [0.86317995],
#        [0.86317995],
#        [0.85523487],
#        [0.8487144 ],
#        [0.85315268],
#        [0.84860487],
#        [0.85276916],
#        [0.84657744],
#        [0.85326229],
#        [0.84290627],
#        [0.88268652],
#        [0.89096043],
#        [0.86981003],
#        [0.85167331],
#        [0.84411174],
#        [0.8388515 ],
#        [0.82767361],
#        [0.83227626],
#        [0.83808439],
#        [0.84970073],
#        [0.85446776],
#        [0.85123495],
#        [0.87424831],
#        [0.8568787 ],
#        [0.85123495],
#        [0.871673  ],
#        [0.92838458],
#        [0.91923404],
#        [0.92301474],
#        [0.92487779],
#        [0.93490506],
#        [0.92657638],
#        [0.94427474],
#        [0.950576  ],
#        [0.96312382],
#        [0.96378131],
#        [0.96394569],
#        [0.97035655],
#        [0.9775346 ],
#        [0.96958944],
#        [0.9475624 ],
#        [0.96454842],
#        [0.96454842],
#        [0.96460327],
#        [0.96624702],
#        [0.97172639],
#        [0.97698663],
#        [0.98673992],
#        [0.98849336],
#        [0.99682195],
#        [0.98920562],
#        [1.00241094],
#        [0.98175366],
#        [1.05862932],
#        [1.0910673 ],
#        [1.09747817],
#        [1.08788926],
#        [1.11079301],
#        [1.09775207],
#        [1.09775207],
#        [1.07249214],
#        [1.06049237],
#        [1.06405393],
#        [1.0691498 ],
#        [1.09205355],
#        [1.09671106],
#        [1.07764276],
#        [1.11123137],
#        [1.1305188 ],
#        [1.1375324 ],
#        [1.1375324 ],
#        [1.16377858],
#        [1.17188812],
#        [1.1766003 ],
#        [1.20016164],
#        [1.17051827],
#        [1.18679195],
#        [1.20794234],
#        [1.21024376],
#        [1.17769624],
#        [1.1519431 ],
#        [1.15265545],
#        [1.15073772],
#        [1.156491  ],
#        [1.12103942],
#        [1.11528614],
#        [1.11786145],
#        [1.11939567],
#        [1.12246411],
#        [1.14043646],
#        [1.12005317],
#        [1.12827224],
#        [1.07024565],
#        [1.05906768],
#        [1.07325933],
#        [1.0923823 ],
#        [1.10843692],
#        [1.11550528],
#        [1.13599818],
#        [1.13846388],
#        [1.15490201],
#        [1.1621896 ],
#        [1.16131288],
#        [1.16471006],
#        [1.16410733],
#        [1.15386092],
#        [1.16651827],
#        [1.16838123],
#        [1.17303874],
#        [1.16460053],
#        [1.18268241],
#        [1.17835374],
#        [1.17835374],
#        [1.14421725],
#        [1.13369685],
#        [1.14208029],
#        [1.13353248],
#        [1.1340256 ],
#        [1.12964208],
#        [1.14361451],
#        [1.14421725],
#        [1.14273779],
#        [1.10887528],
#        [1.11145051],
#        [1.13282013],
#        [1.1776414 ],
#        [1.17397022],
#        [1.16449092],
#        [1.16942233],
#        [1.16394295],
#        [1.17024429],
#        [1.17172366],
#        [1.20027125],
#        [1.16306632],
#        [1.16618952],
#        [1.16010741],
#        [1.16629913],
#        [1.13829951],
#        [1.16065538],
#        [1.18131257],
#        [1.17857288],
#        [1.17040866],
#        [1.19095633],
#        [1.20492875],
#        [1.1935864 ],
#        [1.19561375],
#        [1.21123   ],
#        [1.21933946],
#        [1.21594227],
#        [1.18799741],
#        [1.1869564 ],
#        [1.19155906],
#        [1.20246297],
#        [1.20394242],
#        [1.18438109],
#        [1.16142249],
#        [1.14498435],
#        [1.14005287],
#        [1.14794318],
#        [1.14394326],
#        [1.17002506],
#        [1.16717585],
#        [1.15221709],
#        [1.15221709],
#        [1.15709373],
#        [1.17407983],
#        [1.15643623],
#        [1.17298397],
#        [1.17440858],
#        [1.17835374],
#        [1.17572366],
#        [1.18312077],
#        [1.1995589 ],
#        [1.21155875],
#        [1.21084641],
#        [1.21084641],
#        [1.22399696],
#        [1.23638032],
#        [1.2531472 ],
#        [1.25511978],
#        [1.25528416],
#        [1.2541883 ],
#        [1.27561268],
#        [1.28120167],
#        [1.27418808],
#        [1.28224277],
#        [1.28317425],
#        [1.29911918],
#        [1.31248887],
#        [1.28273589],
#        [1.29226995],
#        [1.31802309],
#        [1.322297  ],
#        [1.33835162],
#        [1.33835162],
#        [1.34284458],
#        [1.32405036],
#        [1.30547527],
#        [1.29572199],
#        [1.29572199],
#        [1.25972252],
#        [1.2570376 ],
#        [1.26602377],
#        [1.25073635],
#        [1.25342119],
#        [1.25342119],
#        [1.22136688],
#        [1.20794234],
#        [1.20180547],
#        [1.22695579],
#        [1.17429897],
#        [1.18372351],
#        [1.18372351],
#        [1.1435049 ],
#        [1.15002537],
#        [1.14909389],
#        [1.14427201],
#        [1.18306601],
#        [1.22909274],
#        [1.23512009],
#        [1.22542157],
#        [1.21670938],
#        [1.17292913],
#        [1.19917539],
#        [1.19736719],
#        [1.20147672],
#        [1.17084702],
#        [1.17095655],
#        [1.19818906],
#        [1.22147641],
#        [1.24701033],
#        [1.26383206],
#        [1.26383206],
#        [1.26311971],
#        [1.26531143],
#        [1.27057167],
#        [1.26903745],
#        [1.2775305 ],
#        [1.27720167],
#        [1.24059947],
#        [1.22383259],
#        [1.24870892],
#        [1.22783251],
#        [1.21632578],
#        [1.21528477],
#        [1.21303821],
#        [1.23353111],
#        [1.17002506],
#        [1.133642  ],
#        [1.11249161],
#        [1.07249214],
#        [1.09336863],
#        [1.09616308],
#        [1.08898511],
#        [1.10295754],
#        [1.09671106],
#        [1.11956005],
#        [1.13303927],
#        [1.14958701],
#        [1.13742279],
#        [1.15013498],
#        [1.11753262],
#        [1.14071045],
#        [1.14651857],
#        [1.15035412],
#        [1.03693103],
#        [0.95578147],
#        [0.91786419],
#        [0.86833058],
#        [1.01315056],
#        [0.96695936],
#        [1.00931492],
#        [1.03325986],
#        [1.03117767],
#        [0.988055  ],
#        [1.00290406],
#        [1.00290406],
#        [0.98197289],
#        [1.0180272 ],
#        [1.04465697],
#        [1.06531416],
#        [1.07030042],
#        [1.07501269],
#        [1.08087566],
#        [1.08794402],
#        [1.09243715],
#        [1.04876651],
#        [1.01336969],
#        [1.0112875 ],
#        [0.99890414],
#        [1.0056986 ],
#        [1.01139711],
#        [1.07857425],
#        [1.09030011],
#        [1.08701253],
#        [1.08219066],
#        [1.08114956],
#        [1.06756073],
#        [1.05704034],
#        [1.03090368],
#        [1.02690376],
#        [0.99353438],
#        [0.99353438],
#        [1.02060251],
#        [1.02175313],
#        [1.01917782],
#        [1.02410931],
#        [1.02876673],
#        [1.03736939],
#        [1.03490369],
#        [1.02290384],
#        [1.04093095],
#        [1.02739689],
#        [1.03408173],
#        [1.01276696],
#        [1.01506829],
#        [1.        ],
#        [1.01079438],
#        [0.99556172],
#        [1.00071235],
#        [1.00071235],
#        [1.02493118],
#        [1.02767087],
#        [1.02109564],
#        [1.02799962],
#        [1.02493118],
#        [1.02536954],
#        [1.04778017],
#        [1.06230057],
#        [1.08761527],
#        [1.09369738],
#        [1.09369738],
#        [1.07397159],
#        [1.07430034],
#        [1.08049206],
#        [1.0874509 ],
#        [1.08060167],
#        [1.06668401],
#        [1.06936893],
#        [1.0751223 ],
#        [1.07435519],
#        [1.0807112 ],
#        [1.08783441],
#        [1.0983548 ],
#        [1.09698496],
#        [1.094848  ],
#        [1.09550559],
#        [1.09643707],
#        [1.08120441],
#        [1.06904018],
#        [1.06093073],
#        [1.03249275],
#        [1.03780775],
#        [1.03545158],
#        [1.09205355],
#        [1.12920372],
#        [1.18027156],
#        [1.16838123],
#        [1.1819153 ],
#        [1.20207945],
#        [1.19906578],
#        [1.19254531],
#        [1.18870976],
#        [1.18690156],
#        [1.16197037],
#        [1.15588826],
#        [1.17155928],
#        [1.16827171],
#        [1.18005233],
#        [1.18651804],
#        [1.19786031],
#        [1.19555898],
#        [1.19555898],
#        [1.1822989 ],
#        [1.23024345],
#        [1.23742142],
#        [1.2369283 ],
#        [1.22701064],
#        [1.20766844],
#        [1.16624428],
#        [1.18399749],
#        [1.20613422],
#        [1.22054493],
#        [1.22849001],
#        [1.23309275],
#        [1.22701064],
#        [1.26876346],
#        [1.3267352 ],
#        [1.31769426],
#        [1.30607801],
#        [1.33106395],
#        [1.3233381 ],
#        [1.31769426],
#        [1.3187902 ],
#        [1.32328325],
#        [1.33248865],
#        [1.3373652 ],
#        [1.33007771],
#        [1.32892708],
#        [1.33758443],
#        [1.31555731],
#        [1.26750323],
#        [1.28059894],
#        [1.28120167],
#        [1.28980425],
#        [1.27944823],
#        [1.3059684 ],
#        [1.36048818],
#        [1.36339225],
#        [1.33972146],
#        [1.34591302],
#        [1.36366631],
#        [1.39648773],
#        [1.39752882],
#        [1.40136446],
#        [1.4106793 ],
#        [1.40503554],
#        [1.39780273],
#        [1.40322742],
#        [1.40377539],
#        [1.40174789],
#        [1.39462476],
#        [1.39988492],
#        [1.43177493],
#        [1.42202165],
#        [1.41917243],
#        [1.41621352],
#        [1.38909054],
#        [1.38898101],
#        [1.39511789],
#        [1.38246054],
#        [1.41117242],
#        [1.43544619],
#        [1.44119947],
#        [1.44437743],
#        [1.44437743],
#        [1.45150072],
#        [1.47478808],
#        [1.49171933],
#        [1.48054135],
#        [1.4616376 ],
#        [1.45111713],
#        [1.44624057],
#        [1.44235009],
#        [1.45111713],
#        [1.44700759],
#        [1.44837744],
#        [1.42552836],
#        [1.42826805],
#        [1.41309024],
#        [1.41500805],
#        [1.42311759],
#        [1.4083232 ],
#        [1.41593945],
#        [1.42388462],
#        [1.42388462],
#        [1.42163805],
#        [1.42361071],
#        [1.41988461],
#        [1.41319976],
#        [1.41319976],
#        [1.40854243],
#        [1.38799476],
#        [1.36114568],
#        [1.35002255],
#        [1.34295428],
#        [1.3447624 ],
#        [1.34958428],
#        [1.35396771],
#        [1.34799521],
#        [1.3384063 ],
#        [1.32372161],
#        [1.32372161],
#        [1.2753387 ],
#        [1.28054409],
#        [1.28437972],
#        [1.28268104],
#        [1.32306411],
#        [1.33873505],
#        [1.32870786],
#        [1.3387899 ],
#        [1.34536522],
#        [1.40306305],
#        [1.40015899],
#        [1.43856931],
#        [1.43539134],
#        [1.44750072],
#        [1.4283229 ],
#        [1.42317227],
#        [1.43314478],
#        [1.35769381],
#        [1.32509145],
#        [1.32509145],
#        [1.36947444],
#        [1.37204975],
#        [1.3513924 ],
#        [1.3733099 ],
#        [1.38207694],
#        [1.41473415],
#        [1.42618603],
#        [1.41917243],
#        [1.37111819],
#        [1.3740771 ],
#        [1.3687621 ],
#        [1.3620224 ],
#        [1.3498035 ],
#        [1.33429677],
#        [1.34755693],
#        [1.35276224],
#        [1.35265271],
#        [1.32498184],
#        [1.29407816],
#        [1.30887254],
#        [1.3165984 ],
#        [1.29309191],
#        [1.28772214],
#        [1.28240714],
#        [1.30158496],
#        [1.30240684],
#        [1.3077766 ],
#        [1.30925606],
#        [1.28684542],
#        [1.27495519],
#        [1.31418746],
#        [1.32426958],
#        [1.32585856],
#        [1.32585856],
#        [1.34196786],
#        [1.31259848],
#        [1.34218708],
#        [1.35089927],
#        [1.35084459],
#        [1.343831  ],
#        [1.34180349],
#        [1.38344679],
#        [1.36684428],
#        [1.40426852],
#        [1.41972024],
#        [1.38202226],
#        [1.4203779 ],
#        [1.42180243],
#        [1.40881633],
#        [1.38991241],
#        [1.40689851],
#        [1.40393977],
#        [1.41040539],
#        [1.45856917],
#        [1.44043227]])

# %%
x_input = test_data[-100:].reshape(1,-1)
print(x_input.shape)
# Out:
# (1, 100)

# %%
temp_input = list(x_input)
temp_input = temp_input[0].tolist()
print(len(temp_input))
# Out:
# 100

# %%
temp_input
# Out:
# [1.4282680500722646,
#  1.413090235721969,
#  1.415008051148099,
#  1.4231175894444654,
#  1.408323204405541,
#  1.4159394516122672,
#  1.423884615284526,
#  1.423884615284526,
#  1.4216380506101818,
#  1.423610713316787,
#  1.419884609808159,
#  1.413199763065601,
#  1.413199763065601,
#  1.4085424263101234,
#  1.40015899 1.43856931 1.43539134 1.44750072 1.4283229  1.42317227
#  1.43314478 1.35769381 1.32509145 1.32509145 1.36947444 1.37204975
#  1.3513924  1.3733099  1.38207694 1.41473415 1.42618603 1.41917243
#  1.37111819 1.3740771  1.3687621  1.3620224  1.3498035  1.33429677
#  1.34755693 1.35276224 1.35265271 1.32498184 1.29407816 1.30887254
#  1.3165984  1.29309191 1.28772214 1.28240714 1.30158496 1.30240684
#  1.3077766  1.30925606 1.28684542 1.27495519 1.31418746 1.32426958
#  1.32585856 1.32585856 1.34196786 1.31259848 1.34218708 1.35089927
#  1.35084459 1.343831   1.34180349 1.38344679 1.36684428 1.40426852
#  1.41972024 1.38202226 1.4203779  1.42180243 1.40881633 1.38991241
#  1.40689851 1.40393977 1.41040539 1.45856917 1.44043227 1.42723954
#  1.41918242 1.41187036 1.40514708 1.39895713 1.39327824 1.38807321
#  1.38329995 1.37891865 1.37489438 1.37119627 1.36779583 1.36466777
#  1.36178863 1.35913682 1.35669434 1.35444331 1.35236835 1.35045552
#  1.34869134 1.34706402 1.34556293 1.34417725 1.34289825 1.34171784
#  1.34062803 1.33962214 1.33869362 1.33783698]
# 29 day output [[1.3370471]]
# [[1.4272395372390747], [1.4191824197769165], [1.4118703603744507], [1.4051470756530762], [1.3989571332931519], [1.3932782411575317], [1.388073205947876], [1.3832999467849731], [1.3789186477661133], [1.374894380569458], [1.3711962699890137], [1.3677958250045776], [1.3646677732467651], [1.3617886304855347], [1.3591368198394775], [1.3566943407058716], [1.3544433116912842], [1.3523683547973633], [1.3504555225372314], [1.3486913442611694], [1.3470640182495117], [1.3455629348754883], [1.34417724609375], [1.3428982496261597], [1.3417178392410278], [1.3406280279159546], [1.339622139930725], [1.338693618774414], [1.3378369808197021], [1.3370471000671387]]

# %%
future_actual = scaler.inverse_transform( np.array(lst_output).reshape(-1,1))
print(future_actual[:10])
# Out:
# [[274.42227919]
#  [272.95183514]
#  [271.61736604]
#  [270.39034979]
#  [269.26066986]
#  [268.22425786]
#  [267.27432594]
#  [266.40319423]
#  [265.60359622]
#  [264.86915741]]

# %%
day_new = np.arange(1,101)
day_pred = np.arange(101,131)

# %%
len(dt)
# Out:
# 3450

# %%
plt.figure(figsize=(10,5))
plt.plot(day_new, dt[3350:])
plt.plot( day_pred, scaler.inverse_transform(lst_output))
plt.title("30-Day Future Forecast")
plt.xlabel("Days")
plt.ylabel("Stock Price")
plt.legend(["Historical Data","Forecast"])
plt.grid(True)
plt.show()

# %%
dt1 = dt.values.tolist()
dt1.extend(scaler.inverse_transform(lst_output))

# %%
plt.figure(figsize=(12,5))
plt.plot(dt1)
plt.title("Apple Stock Price Forecast (Next 30 Days)")
plt.xlabel("Time")
plt.ylabel("Price (USD)")
plt.show()

# %% [markdown]
# ##Volatility Forecasting

# %%
returns = 100 * df['Close'].pct_change().dropna()

# %%
plt.figure(figsize=(12,4))
plt.plot(returns)
plt.title("Daily Returns")
plt.show()

# %%
plt.figure(figsize=(8,4))
plt.hist(returns, bins=50)
plt.title("Distribution of Returns")
plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_pacf
plot_pacf(returns**2)
plt.show()
